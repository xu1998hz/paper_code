# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import RFE
from sklearn.ensemble import IsolationForest
clf_IOF = IsolationForest(behaviour='new', random_state=None, contamination='auto')

# %%
# load in all the data and replace NaNs and merge all three files together
df_grey_3777 = pd.read_csv('NA3777-02_AB-Grey.csv', delimiter='\t', encoding='utf8', header=0)
# remove outliers and NaN data for grey before merge uising Isolation of forest
df_grey_3777 = df_grey_3777.fillna(0)
df_grey_3777 = df_grey_3777.drop(columns=['ROI', 'Class', 'Name', 'Centroid X µm', 'Centroid Y µm'])
classes = clf_IOF.fit_predict(df_grey_3777)
outlier_classes_grey = np.where(classes == -1)[0]
print(len(outlier_classes_grey))
df_grey_3777 = df_grey_3777.drop(df_grey_3777.index[outlier_classes_grey.tolist()])

df_grey_4077 = pd.read_csv('NA4077-02_AB-Grey.csv', delimiter='\t', encoding='utf8', header=0)
# remove outliers and NaN data for grey before merge uising Isolation of forest
df_grey_4077 = df_grey_4077.fillna(0)
df_grey_4077 = df_grey_4077.drop(columns=['ROI', 'Class', 'Name', 'Centroid X µm', 'Centroid Y µm'])
classes = clf_IOF.fit_predict(df_grey_4077)
outlier_classes_grey = np.where(classes == -1)[0]
print(len(outlier_classes_grey))
df_grey_4077 = df_grey_4077.drop(df_grey_4077.index[outlier_classes_grey.tolist()])

df_grey_4092 = pd.read_csv('NA4092-02_AB-Grey.csv', delimiter='\t', encoding='utf8', header=0)
# remove outliers and NaN data for grey before merge uising Isolation of forest
df_grey_4092 = df_grey_4092.fillna(0)
df_grey_4092 = df_grey_4092.drop(columns=['ROI', 'Class', 'Name', 'Centroid X µm', 'Centroid Y µm'])
classes = clf_IOF.fit_predict(df_grey_4092)
outlier_classes_grey = np.where(classes == -1)[0]
print(len(outlier_classes_grey))
df_grey_4092 = df_grey_4092.drop(df_grey_4092.index[outlier_classes_grey.tolist()])

df_grey_4107 = pd.read_csv('NA4107-02_AB-Grey.csv', delimiter='\t', encoding='utf8', header=0)
# remove outliers and NaN data for grey before merge uising Isolation of forest
df_grey_4107 = df_grey_4107.fillna(0)
df_grey_4107 = df_grey_4107.drop(columns=['ROI', 'Class', 'Name', 'Centroid X µm', 'Centroid Y µm'])
classes = clf_IOF.fit_predict(df_grey_4107)
outlier_classes_grey = np.where(classes == -1)[0]
print(len(outlier_classes_grey))
df_grey_4107 = df_grey_4107.drop(df_grey_4107.index[outlier_classes_grey.tolist()])

df_grey = pd.concat([df_grey_3777, df_grey_4077, df_grey_4092, df_grey_4107], ignore_index=True)
# Out:
# 32817
# 49750
# 57969
# 71437

# %%
df_white_3077 = pd.read_csv('NA3777-02_AB-White.csv', delimiter='\t', encoding='utf8', header=0)
# remove outliers and NaN data for white before merge using Isolation of forest
df_white_3077 = df_white_3077.fillna(0)
df_white_3077 = df_white_3077.drop(columns=['ROI', 'Class', 'Name', 'Centroid X µm', 'Centroid Y µm'])
classes = clf_IOF.fit_predict(df_white_3077)
outlier_classes_white = np.where(classes == -1)[0]
print(len(outlier_classes_white))
df_white_3077 = df_white_3077.drop(df_white_3077.index[outlier_classes_white.tolist()])

df_white_4077 = pd.read_csv('NA4077-02_AB-White.csv', delimiter='\t', encoding='utf8', header=0)
# remove outliers and NaN data for white before merge using Isolation of forest
df_white_4077 = df_white_4077.fillna(0)
df_white_4077 = df_white_4077.drop(columns=['ROI', 'Class', 'Name', 'Centroid X µm', 'Centroid Y µm'])
classes = clf_IOF.fit_predict(df_white_4077)
outlier_classes_white = np.where(classes == -1)[0]
print(len(outlier_classes_white))
df_white_4077 = df_white_4077.drop(df_white_4077.index[outlier_classes_white.tolist()])

df_white_4092 = pd.read_csv('NA4092-02_AB-White.csv', delimiter='\t', encoding='utf8', header=0)
# remove outliers and NaN data for white before merge using Isolation of forest
df_white_4092 = df_white_4092.fillna(0)
df_white_4092 = df_white_4092.drop(columns=['ROI', 'Class', 'Name', 'Centroid X µm', 'Centroid Y µm'])
classes = clf_IOF.fit_predict(df_white_4092)
outlier_classes_white = np.where(classes == -1)[0]
print(len(outlier_classes_white))
df_white_4092 = df_white_4092.drop(df_white_4092.index[outlier_classes_white.tolist()])

df_white_4107 = pd.read_csv('NA4107-02_AB-White.csv', delimiter='\t', encoding='utf8', header=0)
# remove outliers and NaN data for white before merge using Isolation of forest
df_white_4107 = df_white_4107.fillna(0)
df_white_4107 = df_white_4107.drop(columns=['ROI', 'Class', 'Name', 'Centroid X µm', 'Centroid Y µm'])
classes = clf_IOF.fit_predict(df_white_4107)
outlier_classes_white = np.where(classes == -1)[0]
print(len(outlier_classes_white))
df_white_4107 = df_white_4107.drop(df_white_4107.index[outlier_classes_white.tolist()])

df_white = pd.concat([df_white_3077, df_white_4077, df_white_4092, df_white_4107], ignore_index=True)
# Out:
# 33353
# 15299
# 23033
# 22391

# %%
df_grey['white_grey'] = np.zeros((len(df_grey),))
df_white['white_grey'] = np.ones((len(df_white),))

# %%
# merge, shuffle and split data
result = pd.concat([df_grey, df_white], ignore_index=True)
result = result.sample(frac=1).reset_index(drop=True)

# %%
# construct a training and testing dataset
msk = np.random.rand(len(result)) < 0.66
train = result[msk]
test = result[~msk]
train
# Out:
#          Nucleus: Area  Nucleus: Perimeter  Nucleus: Circularity  \
# 0              10.1083             12.3167                0.8373
# 1              13.8989             14.5291                0.8274
# 4              13.6462             13.8345                0.8960
# 5              28.3032             20.2384                0.8683
# 6              11.8772             14.4205                0.7177
# ...                ...                 ...                   ...
# 2774791        19.4585             16.9231                0.8538
# 2774792        28.3032             20.7690                0.8245
# 2774793        17.1841             15.7851                0.8666
# 2774794        19.7112             17.5615                0.8032
# 2774795        14.1516             13.5343                0.9708
#
#          Nucleus: Max caliper  Nucleus: Min caliper  Nucleus: Eccentricity  \
# 0                      4.3244                3.1561                 0.6648
# ...

# %%
from keras import Sequential
from keras.layers import Dense

# %%
import keras
normal = keras.initializers.RandomNormal(mean=0.0, stddev=1, seed=1)

classifier = Sequential()
# first hidden layer
classifier.add(Dense(128, activation='selu', use_bias=True, kernel_initializer=normal, input_dim=33))

# second hidden layer
classifier.add(Dense(128, activation='selu', use_bias=True, kernel_initializer=normal))

# third hidden layer
classifier.add(Dense(16, activation='relu', use_bias=True, kernel_initializer=normal))

# output layer
classifier.add(Dense(2, activation='softmax', use_bias=True, kernel_initializer=normal))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/Keras-2.3.1-py3.6.egg/keras/backend/tensorflow_backend.py:3313: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
from keras import optimizers
adam = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
#sgd = optimizers.SGD(lr=0.01)
classifier.compile(loss="categorical_crossentropy", optimizer=adam, metrics=['accuracy'])

# %%
# reconstruct data for training 
X_train = train.drop(columns=['white_grey'])
Y_train = np.array(train['white_grey'])
X_test = test.drop(columns=['white_grey'])
Y_test = np.array(test['white_grey'])

temp_ls = []
test_ls = []
for ele in Y_train:
    temp = [0] * 2
    temp[int(ele)] = 1
    temp_ls.append(temp)
    
for ele in Y_test:
    temp = [0] * 2
    temp[int(ele)] = 1 
    test_ls.append(temp)
Y_train = np.array(temp_ls)
Y_test = np.array(test_ls)

# %%
# Try univariate feature selection. Univariate feature selection works by selecting the best features based 
# on univariate statistical tests. 
# Use selectBest to remove all but the k highest scoring features
# Use mutual_info_classif because they can capture any kind of statistical dependency but being non-parametric 
# they require more samples for accurate estimation
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

# %%
Y = np.argmax(Y_train, axis=1)
X_new = SelectKBest(chi2, k=2).fit_transform(X_train, Y)

# %%
classifier.fit(X_train, Y_train, validation_data=(X_test, Y_test), batch_size=100, epochs=20)
